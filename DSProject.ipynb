# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Pistachio_16_Features_Dataset.xlsx')
print(df.head)
# Out:
# <bound method NDFrame.head of         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0      63391  1568.4050    390.3396    236.7461        0.7951  284.0984
# 1      68358  1942.1870    410.8594    234.7525        0.8207  295.0188
# 2      73589  1246.5380    452.3630    220.5547        0.8731  306.0987
# 3      71106  1445.2610    429.5291    216.0765        0.8643  300.8903
# 4      80087  1251.5240    469.3783    220.9344        0.8823  319.3273
# ...      ...        ...         ...         ...           ...       ...
# 2143   85983  1157.1160    444.3447    248.8627        0.8284  330.8730
# 2144   85691  2327.3459    439.8794    278.9297        0.7732  330.3107
# 2145  101136  1255.6190    475.2161    271.3299        0.8210  358.8459
# 2146   97409  1195.2150    452.1823    274.5764        0.7945  352.1718
# 2147   78466  2356.9080    445.9131    258.5125        0.8148  316.0791
#
# ...

# %%
lis=df['Class'].value_counts();
print((lis[0]+lis[1]),"Total Records")
print(lis[0],"Kirmizi_Pistachio")
print(lis[1],"Siit_Pistachio")
# Out:
# 2148 Total Records
# 1232 Kirmizi_Pistachio
# 916 Siit_Pistachio

# %%
#shuffle the data
from sklearn.utils import shuffle
df = shuffle(df)

# %%
y = df["Class"].values;
x = df.drop(["Class"],axis=1).values
print(y)
# Out:
# ['Siit_Pistachio' 'Siit_Pistachio' 'Siit_Pistachio' ...
#  'Kirmizi_Pistachio' 'Siit_Pistachio' 'Kirmizi_Pistachio']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)
df['Class']=y
print(df['Class'].value_counts())

# 0 represent kirzmi
# 1 represent Siit
# Out:
# 0    1232
# 1     916
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %% [markdown]
# #Calling Model before preprocessing

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score



def trainModel(x_train, x_test, y_train, y_test):
    classifier = KNeighborsClassifier(n_neighbors=11)
    classifier.fit(x_train, y_train)
    y_pred = classifier.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    return acc

trainModel(x_train, x_test, y_train, y_test)
# Out:
# 0.786046511627907

# %%
arr=np.array(df.columns);
arr
# Out:
# array(['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY',
#        'EQDIASQ', 'SOLIDITY', 'CONVEX_AREA', 'EXTENT', 'ASPECT_RATIO',
#        'ROUNDNESS', 'COMPACTNESS', 'SHAPEFACTOR_1', 'SHAPEFACTOR_2',
#        'SHAPEFACTOR_3', 'SHAPEFACTOR_4', 'Class'], dtype=object)

# %%
df.describe().T
# Out:
#                 count          mean           std         min           25%  \
# AREA           2148.0  79950.655493  13121.737799  29808.0000  71936.750000
# PERIMETER      2148.0   1425.971751    375.565503    858.3630   1170.996250
# MAJOR_AXIS     2148.0    446.248968     32.445304    320.3445    426.508750
# MINOR_AXIS     2148.0    238.311842     30.310695    133.5096    217.875825
# ECCENTRICITY   2148.0      0.840219      0.048759      0.5049      0.817500
# EQDIASQ        2148.0    317.919173     26.908600    194.8146    302.642850
# SOLIDITY       2148.0      0.940093      0.050452      0.5880      0.919850
# CONVEX_AREA    2148.0  85015.839851  13154.919327  37935.0000  76467.000000
# EXTENT         2148.0      0.716067      0.052532      0.4272      0.687000
# ASPECT_RATIO   2148.0      1.898154      0.240100      1.1585      1.736375
# ROUNDNESS      2148.0      0.569172      0.212760      0.0628      0.371250
# ...

# %% [markdown]
# #Data Visulization (box plot)

# %%
boxplot=df.boxplot(column=['AREA','CONVEX_AREA']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
boxplot=df.boxplot(column=['PERIMETER']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
boxplot=df.boxplot(column=['MAJOR_AXIS','MINOR_AXIS',
       'EQDIASQ']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
boxplot=df.boxplot(column=['ECCENTRICITY']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
boxplot=df.boxplot(column=['SOLIDITY','EXTENT', 'ASPECT_RATIO',
       'ROUNDNESS', 'COMPACTNESS']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
boxplot=df.boxplot(column=['SHAPEFACTOR_1', 'SHAPEFACTOR_2',
       'SHAPEFACTOR_3', 'SHAPEFACTOR_4']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# #Check distributions through histograms

# %%
df.hist(figsize=(12,12), bins=20);

# %% [markdown]
# #check correlation with heatmap

# %%
import seaborn as sns
plt.figure(figsize=(30,30))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# #Correlation with scatter plot (each variable)

# %%
import seaborn as sns
sns.regplot(x=df["AREA"], y=df["CONVEX_AREA"])

# %%
import seaborn as sns
sns.regplot(x=df["AREA"], y=df["EQDIASQ"])

# %%
import seaborn as sns
sns.regplot(x=df["AREA"], y=df["SOLIDITY"])

# %%
arr=np.array(df.columns);
arr
# Out:
# array(['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY',
#        'EQDIASQ', 'SOLIDITY', 'CONVEX_AREA', 'EXTENT', 'ASPECT_RATIO',
#        'ROUNDNESS', 'COMPACTNESS', 'SHAPEFACTOR_1', 'SHAPEFACTOR_2',
#        'SHAPEFACTOR_3', 'SHAPEFACTOR_4', 'Class'], dtype=object)

# %% [markdown]
# #normalize the whole data

# %%
from sklearn import preprocessing
import pandas as pd

column ='AREA'
df[column]=df[column] /df[column].abs().max()
column='PERIMETER'
df[column]=df[column] /df[column].abs().max()
column='MAJOR_AXIS'
df[column]=df[column] /df[column].abs().max()
column='MINOR_AXIS'
df[column]=df[column] /df[column].abs().max()
column='ECCENTRICITY'
df[column]=df[column] /df[column].abs().max()
column='EQDIASQ'
df[column]=df[column] /df[column].abs().max()
column='SOLIDITY'
df[column]=df[column] /df[column].abs().max()
column='CONVEX_AREA'
df[column]=df[column] /df[column].abs().max()
column='EXTENT'
df[column]=df[column] /df[column].abs().max()
column='ASPECT_RATIO'
df[column]=df[column] /df[column].abs().max()
column='ROUNDNESS'
df[column]=df[column] /df[column].abs().max()
column='COMPACTNESS'
df[column]=df[column] /df[column].abs().max()
column='SHAPEFACTOR_1'
df[column]=df[column] /df[column].abs().max()
column='SHAPEFACTOR_2'
df[column]=df[column] /df[column].abs().max()
column='SHAPEFACTOR_3'
df[column]=df[column] /df[column].abs().max()
column='SHAPEFACTOR_4'
df[column]=df[column] /df[column].abs().max()

# %% [markdown]
# #After normalization calling model

# %%
y = df["Class"].values;
x = df.drop(["Class"],axis=1).values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
acc=trainModel(x_train,x_test,y_train,y_test)
print(acc)
# Out:
# 0.8558139534883721

# %% [markdown]
# #Now removing other issues
# 1. duplicate rows (if any)
# 2. correlation matrix upper triangular
# 3. outliers

# %%
#Remove duplicates
df.drop_duplicates(subset=None, keep='first', inplace=True)
print(df);
# Out:
#           AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 1983  0.743331   0.437614    0.884010    0.642044      0.907188  0.862166
# 1482  0.801602   0.440456    0.857691    0.712617      0.855603  0.895322
# 1568  0.644144   0.416684    0.851828    0.643373      0.893869  0.802586
# 489   0.720655   0.460343    0.936060    0.590967      0.945983  0.848914
# 746   0.497839   0.662385    0.739346    0.643417      0.833510  0.705577
# ...        ...        ...         ...         ...           ...       ...
# 567   0.602082   0.429446    0.848017    0.551904      0.938584  0.775940
# 582   0.622492   0.432454    0.840549    0.581615      0.922093  0.788982
# 1042  0.614186   0.407670    0.844190    0.559061      0.934144  0.783700
# 1852  0.725268   0.623857    0.855341    0.660382      0.885835  0.851627
# 831   0.587438   0.398042    0.765102    0.605779      0.876110  0.766445
#
#       SOLIDITY  CONVEX_AREA    EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# ...

# %% [markdown]
# #correlation Remove, show heatmap , call model

# %%
#correlation code
cor_matrix = df.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.90)]
data = df.drop(to_drop, axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2148 entries, 1983 to 831
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           2148 non-null   float64
#  1   PERIMETER      2148 non-null   float64
#  2   MAJOR_AXIS     2148 non-null   float64
#  3   MINOR_AXIS     2148 non-null   float64
#  4   ECCENTRICITY   2148 non-null   float64
#  5   SOLIDITY       2148 non-null   float64
#  6   EXTENT         2148 non-null   float64
#  7   ROUNDNESS      2148 non-null   float64
#  8   COMPACTNESS    2148 non-null   float64
#  9   SHAPEFACTOR_2  2148 non-null   float64
#  10  Class          2148 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 201.4 KB
# ...

# %%
arr=np.array(data.columns);
arr
# Out:
# array(['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY',
#        'SOLIDITY', 'EXTENT', 'ROUNDNESS', 'COMPACTNESS', 'SHAPEFACTOR_2',
#        'Class'], dtype=object)

# %%
#heatmap code
import seaborn as sns
plt.figure(figsize=(30,30))
cor = data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
y = data["Class"].values;
x = data.drop(["Class"],axis=1).values
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
trainModel(x_train, x_test, y_train, y_test)
# Out:
# 0.8604651162790697

# %% [markdown]
# #Remove outliers

# %%
#Removing outliers
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-(1.5*iqr)
    fence_high = q3+(1.5*iqr)
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out
for c in data.columns[:-1]:
    data = remove_outlier(data, c)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1806 entries, 1983 to 831
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           1806 non-null   float64
#  1   PERIMETER      1806 non-null   float64
#  2   MAJOR_AXIS     1806 non-null   float64
#  3   MINOR_AXIS     1806 non-null   float64
#  4   ECCENTRICITY   1806 non-null   float64
#  5   SOLIDITY       1806 non-null   float64
#  6   EXTENT         1806 non-null   float64
#  7   ROUNDNESS      1806 non-null   float64
#  8   COMPACTNESS    1806 non-null   float64
#  9   SHAPEFACTOR_2  1806 non-null   float64
#  10  Class          1806 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 169.3 KB

# %% [markdown]
# #Call the model again after removing outliers

# %%
y = data["Class"].values;
x = data.drop(["Class"],axis=1).values
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
trainModel(x_train, x_test, y_train, y_test)
# Out:
# 0.8560885608856088

# %% [markdown]
# #Show the boxplot after removing outliers (for understanding)

# %%
arr=np.array(data.columns);
arr
# Out:
# array(['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY',
#        'SOLIDITY', 'EXTENT', 'ROUNDNESS', 'COMPACTNESS', 'SHAPEFACTOR_2',
#        'Class'], dtype=object)

# %%
boxplot=data.boxplot(column=['AREA']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
boxplot=data.boxplot(column=['PERIMETER']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
boxplot=data.boxplot(column=['MAJOR_AXIS','MINOR_AXIS',
       'ECCENTRICITY']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
boxplot=data.boxplot(column=['SOLIDITY','EXTENT',
       'ROUNDNESS', 'COMPACTNESS']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
boxplot=data.boxplot(column=['SHAPEFACTOR_2']);
print(boxplot)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# #after removing outliers check histograms for distributions

# %%
# We can see the distribution are now some how normal after removing outliers only
data.hist(figsize=(12,12), bins=20);

# %% [markdown]
# #call model after preprocessing

# %%
y = data["Class"].values;
x = data.drop(["Class"],axis=1).values
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
trainModel(x_train, x_test, y_train, y_test)
# Out:
# 0.8597785977859779

# %% [markdown]
# #Now check for data imbalance

# %%
plt.figure(figsize=(15,5))
sns.countplot(data['Class'], label="Class",color="salmon", facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("BrBG", 2))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #So we examine the class Siit_Pistachio has less value
# #so apply smote

# %%
from sklearn import model_selection
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, make_scorer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, RepeatedKFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from imblearn.over_sampling import SMOTE


X = data.iloc[:, :-1]
Y = data.iloc[:, -1]

# standardize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# transform the dataset
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)
data=pd.DataFrame(X)
data["Class"]=Y
print(len(X), len(Y))
plt.rcParams.update({'figure.figsize':(10,5), 'figure.dpi':100})
sns.countplot(Y,x = 'Class', label="Class",color="salmon", facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("BrBG", 2))
# Out:
# 2098 2098
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# data.sample(frac=1)

# %%
#shuffle the data after smote
from sklearn.utils import shuffle
data = shuffle(data)
data
# Out:
#              0         1         2         3         4         5         6  \
# 1752 -0.181148 -0.860379 -0.560564 -0.154455 -0.079954  1.172606  1.824600
# 1080 -1.799886 -1.084704 -1.152095 -1.914950  1.256250  0.946407  0.460627
# 462  -0.084422  1.616472 -0.828984  0.747468 -1.279253 -0.993325 -0.533623
# 725   2.291029 -0.001225  1.280652  1.804859 -0.923297  0.980492  1.075164
# 1436  0.141386 -0.379288  0.590444  0.017958  0.385527 -0.469660  0.695450
# ...        ...       ...       ...       ...       ...       ...       ...
# 378  -0.862041 -0.417788  0.656955 -1.371680  1.516372 -0.311630 -0.246340
# 383   0.458107 -0.355294  1.729989 -0.487093  1.258988  0.834857  0.570545
# 735  -0.499777 -0.654414  0.126949 -0.842441  0.905770  0.397952  0.248287
# 1448 -0.688023  0.222112 -0.930910 -0.384668 -0.069002 -0.460364  0.413163
# 131  -0.875661  1.050591 -1.979219  0.158438 -1.511994 -1.086284 -0.063977
#
#              7         8         9  Class
# ...

# %% [markdown]
# #after oversampling (smote) train the model and call
# hence the accuracy increase

# %% [markdown]
# #find maximum error rate at K value

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
import numpy as np
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(x_train,y_train)
 pred_i = knn.predict(x_test)
 error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed',
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Maximum error:-",max(error_rate),"at K =",error_rate.index(max(error_rate)))
# Out:
# Maximum error:- 0.21033210332103322 at K = 0

# %% [markdown]
# #find the best value for k (accuracy)

# %%
#find the best value for k
acc = []
# Will take some time
from sklearn import metrics
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(x_train,y_train)
    yhat = neigh.predict(x_test)
    acc.append(metrics.accuracy_score(y_test, yhat))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed',
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
print("Maximum accuracy:-",max(acc),"at K =",acc.index(max(acc)))
# Out:
# Maximum accuracy:- 0.8708487084870848 at K = 11

# %% [markdown]
# #Train Model again

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score



def trainModel(x_train, x_test, y_train, y_test):
    classifier = KNeighborsClassifier(n_neighbors=24)
    classifier.fit(x_train, y_train)
    y_pred = classifier.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    return acc

trainModel(x_train, x_test, y_train, y_test)
# Out:
# 0.8837638376383764

# %% [markdown]
# #Now Model Performance with confusion matrix (Precision, recall)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, RepeatedKFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier

X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=42, stratify=Y)

model = KNeighborsClassifier(15)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0    1  All
# True
# 0          269   46  315
# 1           32  283  315
# All        301  329  630

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87       315
#            1       0.86      0.90      0.88       315
#
#     accuracy                           0.88       630
#    macro avg       0.88      0.88      0.88       630
# weighted avg       0.88      0.88      0.88       630

# %% [markdown]
# # Different classifiers and ROC curve

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size =0.3, random_state = 0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1468, 10)
# (630, 10)
# (1468,)
# (630,)

# %%
from sklearn.preprocessing import StandardScaler
SC = StandardScaler()
X_train = SC.fit_transform(X_train)

# %%
from sklearn.linear_model import LogisticRegression
model_LR = LogisticRegression()
model_LR.fit(X_train,y_train)
prob_LR = model_LR.predict_proba(SC.transform(X_test))[:,1]

# %%
from sklearn.neighbors import KNeighborsClassifier
model_KNC = KNeighborsClassifier(15)
model_KNC.fit(X_train,y_train)
prob_KNC = model_KNC.predict_proba(SC.transform(X_test))[:,1]

# %%
from sklearn.naive_bayes import GaussianNB
model_NB = GaussianNB()
model_NB.fit(X_train,y_train)
prob_NB = model_NB.predict_proba(SC.transform(X_test))[:,1]

# %%
from sklearn.tree import DecisionTreeClassifier
model_DT = DecisionTreeClassifier(criterion='entropy')
model_DT.fit(X_train,y_train)
prob_DT = model_DT.predict_proba(SC.transform(X_test))[:,1]

# %%
from sklearn.ensemble import RandomForestClassifier
model_RF = RandomForestClassifier()
model_RF.fit(X_train,y_train)
prob_RF = model_RF.predict_proba(SC.transform(X_test))[:,1]

# %%
# Visualize the ROC curves and calculate the AUC
from sklearn.metrics import roc_curve, auc, roc_auc_score
y_test = pd.Series(y_test).replace({'Good':1, 'Bed':0})

roc_score_LR = roc_auc_score(y_test, prob_LR)
fpr_LR, tpr_LR, threshold_LR = roc_curve(y_test, prob_LR)
auc_LR = auc(fpr_LR, tpr_LR)

roc_score_KNC = roc_auc_score(y_test, prob_KNC)
fpr_KNC, tpr_KNC, threshold_KNC = roc_curve(y_test, prob_KNC)
auc_KNC = auc(fpr_KNC, tpr_KNC)


roc_score_NB = roc_auc_score(y_test, prob_NB)
fpr_NB, tpr_NB, threshold_NB = roc_curve(y_test, prob_NB)
auc_NB = auc(fpr_NB, tpr_NB)

roc_score_DT = roc_auc_score(y_test, prob_DT)
fpr_DT, tpr_DT, threshold_DT = roc_curve(y_test, prob_DT)
auc_DT = auc(fpr_DT, tpr_DT)

roc_score_RF = roc_auc_score(y_test, prob_RF)
fpr_RF, tpr_RF, threshold_RF = roc_curve(y_test, prob_RF)
auc_RF = auc(fpr_RF, tpr_RF)


plt.figure(figsize=(12,7))
plt.plot(fpr_LR, tpr_LR, label = f'AUC (Logistic Regression Classifier ) = {roc_score_LR:.2f}', linewidth = 4)
plt.plot(fpr_KNC, tpr_KNC, label = f'AUC (KNeighbours Classifier ) = {roc_score_KNC:.2f}', linewidth = 4)
# plt.plot(fpr_SVC, tpr_SVC, label = f'AUC (Support Vector Classifier ) = {roc_score_SVC:.2f}', linewidth = 4)
plt.plot(fpr_NB, tpr_NB, label = f'AUC (Neive Bayes Classifier ) = {roc_score_NB:.2f}', linewidth = 4)
plt.plot(fpr_DT, tpr_DT, label = f'AUC (Decision Tree Classifier ) = {roc_score_DT:.2f}', linewidth = 4)
plt.plot(fpr_RF, tpr_RF, label = f'AUC (Random Forest Classifier ) = {roc_score_RF:.2f}', linewidth = 4)
plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
plt.title('ROC Curve', size=20)
plt.xlabel('False Positive Rate', size=14)
plt.ylabel('True Positive Rate', size=14)
plt.legend();
